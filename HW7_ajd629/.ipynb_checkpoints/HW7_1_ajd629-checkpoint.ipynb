# %%
# my usual imports and setups
import pylab as pl
import pandas as pd
import numpy as np
import os
import sys

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
##Function to download and unpack Citibike data.
##Moves the data to the directory pointed to by $PUIDATA

#check if the env variable PUIDATA exists
if os.getenv("PUIDATA") is None:
    print ("must set PUIDATA env variable")
    sys.exit()


def getCitiBikeCSV(datestring):
    
    '''Downloads citibike data and unzips it. If the data is downloaded by not unzippeds it zips it. 
        Moves the data to $PUIDATA. Arguments: date string as yyyymm
    '''
    
    print ("Downloading", datestring)
    if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
        
        if os.path.isfile(datestring + "-citibike-tripdata.csv"):
            if os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA")):
                print ("Error moving file!, Please check!")

        else:
            if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip"):
                if not os.path.isfile(datestring + "-citibike-tripdata.zip"):
                    os.system("curl -O https://s3.amazonaws.com/tripdata/" + datestring + "-citibike-tripdata.zip")
                
                os.system("mv " + datestring + "-citibike-tripdata.zip " + os.getenv("PUIDATA"))
            
            os.system("unzip " + os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip")
            
            ## NOTE: old csv citibike data had a different name structure. 
            if '2014' in datestring:
                os.system("mv " + datestring[:4] + '-' +  datestring[4:] + 
                    "\ -\ Citi\ Bike\ trip\ data.csv " + datestring + "-citibike-tripdata.csv")
            
            os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA"))
    
    ### One final check:
    if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
        print ("WARNING!!! something is wrong: the file is not there!")

    else:
        print ("file in place, you can continue")

# %%
datestring = '201506'        
getCitiBikeCSV(datestring)
# Out:
# ('Downloading', '201506')
# file in place, you can continue

# %%
df = pd.read_csv(os.getenv("PUIDATA") + "/" + datestring + '-citibike-tripdata.csv')
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# 2               -74.000271             388         W 26 St & 10 Ave
# 3               -73.991908             531   Forsyth St & Broome St
# 4               -73.992005             532          S 5 Pl & S 4 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.759291             -73.988597   20721  Subscriber
# 1             40.722055             -73.989111   21606  Subscriber
# 2             40.749718             -74.002950   16595  Subscriber
# 3             40.718939             -73.992663   16949  Subscriber
# 4             40.710451             -73.960876   17028    Customer
#
#    birth year  gender
# 0      1984.0       1
# 1      1997.0       1
# 2      1993.0       1
# 3      1981.0       1
# 4         NaN       0

# %%
df.columns
# Out:
# Index([u'tripduration', u'starttime', u'stoptime', u'start station id',
#        u'start station name', u'start station latitude',
#        u'start station longitude', u'end station id', u'end station name',
#        u'end station latitude', u'end station longitude', u'bikeid',
#        u'usertype', u'birth year', u'gender'],
#       dtype='object')

# %%
df['ageS'] = 2015 - df['birth year'][(df['usertype'] == 'Subscriber')]
df['ageC'] = 2015 - df['birth year'][(df['usertype'] == 'Customer')]
df['age'] = 2015 - df['birth year']
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# 2               -74.000271             388         W 26 St & 10 Ave
# 3               -73.991908             531   Forsyth St & Broome St
# 4               -73.992005             532          S 5 Pl & S 4 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.759291             -73.988597   20721  Subscriber
# 1             40.722055             -73.989111   21606  Subscriber
# 2             40.749718             -74.002950   16595  Subscriber
# 3             40.718939             -73.992663   16949  Subscriber
# 4             40.710451             -73.960876   17028    Customer
#
#    birth year  gender  ageS  ageC   age
# 0      1984.0       1  31.0   NaN  31.0
# 1      1997.0       1  18.0   NaN  18.0
# 2      1993.0       1  22.0   NaN  22.0
# 3      1981.0       1  34.0   NaN  34.0
# 4         NaN       0   NaN   NaN   NaN

# %%
df1 = df.drop([u'starttime', u'stoptime', u'start station id',
       u'start station name', u'start station latitude',
       u'start station longitude', u'end station id', u'end station name',
       u'end station latitude', u'end station longitude', u'bikeid',
       u'birth year'],axis = 1)
df1.head()
# Out:
#    tripduration    usertype  gender  ageS  ageC   age
# 0          1338  Subscriber       1  31.0   NaN  31.0
# 1           290  Subscriber       1  18.0   NaN  18.0
# 2           634  Subscriber       1  22.0   NaN  22.0
# 3           159  Subscriber       1  34.0   NaN  34.0
# 4          1233    Customer       0   NaN   NaN   NaN

# %%
df1 = df1[df1.gender != 0]
df1.gender.replace(to_replace=1, value = 'Male', inplace = True)
df1.gender.replace(to_replace=2, value = 'Female', inplace = True)

# %%
df1.boxplot(column='tripduration', by = 'gender', sym = '' )
#pl.ylim(0,100)
pl.title("BoxPlot grouped by gender")
pl.ylabel('Age of Subscribers')
pl.xlabel("")
pl.suptitle("")

# %%
df.boxplot(column='tripduration', by = 'usertype', sym = '' )
# pl.ylim(0,100)
pl.title("BoxPlot grouped by gender")
pl.ylabel('Age of Subscribers')
pl.xlabel("")
pl.suptitle("")

# %%
(df[df.usertype == 'Customer'])
# Out:
#         tripduration        starttime         stoptime  start station id  \
# 4               1233    6/1/2015 0:02    6/1/2015 0:22               382
# 25               160    6/1/2015 0:22    6/1/2015 0:25               368
# 36               597    6/1/2015 0:29    6/1/2015 0:39               447
# 59               261    6/1/2015 0:45    6/1/2015 0:49               405
# 66               708    6/1/2015 0:50    6/1/2015 1:01               500
# 69               665    6/1/2015 0:50    6/1/2015 1:01               500
# 122             1006    6/1/2015 1:41    6/1/2015 1:58               393
# 124              861    6/1/2015 1:43    6/1/2015 1:57               335
# 125              807    6/1/2015 1:44    6/1/2015 1:57               335
# 132             2874    6/1/2015 1:55    6/1/2015 2:43               417
# 134             3427    6/1/2015 1:56    6/1/2015 2:53               417
# 161              738    6/1/2015 2:40    6/1/2015 2:52               383
# 165              134    6/1/2015 2:43    6/1/2015 2:46               523
# 184              246    6/1/2015 4:48    6/1/2015 4:52               523
# 238              818    6/1/2015 5:41    6/1/2015 5:54               216
# 240              796    6/1/2015 5:41    6/1/2015 5:54               216
# 329              633    6/1/2015 6:06    6/1/2015 6:16               293
# 401             2210    6/1/2015 6:17    6/1/2015 6:54               498
# 580              363    6/1/2015 6:36    6/1/2015 6:43               521
# 658              456    6/1/2015 6:43    6/1/2015 6:51               270
# 675              402    6/1/2015 6:45    6/1/2015 6:51               270
# 759              420    6/1/2015 6:55    6/1/2015 7:02              3002
# 780              393    6/1/2015 6:57    6/1/2015 7:03               486
# 868              606    6/1/2015 7:04    6/1/2015 7:14               250
# 950              650    6/1/2015 7:11    6/1/2015 7:22               477
# 975              353    6/1/2015 7:13    6/1/2015 7:19               476
# 1039            1629    6/1/2015 7:18    6/1/2015 7:45               368
# 1048            1457    6/1/2015 7:19    6/1/2015 7:43               509
# 1049            1462    6/1/2015 7:19    6/1/2015 7:43               509
# 1064            1736    6/1/2015 7:20    6/1/2015 7:48               509
# ...              ...              ...              ...               ...
# 940998           342  6/30/2015 23:35  6/30/2015 23:41               527
# 941002           325  6/30/2015 23:36  6/30/2015 23:41               527
# 941012           303  6/30/2015 23:37  6/30/2015 23:42               527
# 941034          1581  6/30/2015 23:38    7/1/2015 0:04               467
# 941048           659  6/30/2015 23:40  6/30/2015 23:51               151
# 941057           980  6/30/2015 23:41  6/30/2015 23:57               392
# 941058           912  6/30/2015 23:41  6/30/2015 23:56               392
# 941078          2002  6/30/2015 23:43    7/1/2015 0:16               537
# 941089          1428  6/30/2015 23:45    7/1/2015 0:08               527
# 941101          1372  6/30/2015 23:45    7/1/2015 0:08               527
# 941102          1370  6/30/2015 23:45    7/1/2015 0:08               527
# 941119          1380  6/30/2015 23:48    7/1/2015 0:11               392
# 941120          1365  6/30/2015 23:48    7/1/2015 0:11               392
# 941126           679  6/30/2015 23:48    7/1/2015 0:00               254
# 941141           523  6/30/2015 23:50  6/30/2015 23:58               282
# 941149           461  6/30/2015 23:51  6/30/2015 23:58               282
# 941152           219  6/30/2015 23:51  6/30/2015 23:55               250
# 941161          1950  6/30/2015 23:52    7/1/2015 0:24               375
# 941168          1567  6/30/2015 23:52    7/1/2015 0:18               212
# 941177           530  6/30/2015 23:53    7/1/2015 0:02               334
# 941178           532  6/30/2015 23:53    7/1/2015 0:02               334
# 941192           710  6/30/2015 23:56    7/1/2015 0:08               527
# 941193          1954  6/30/2015 23:57    7/1/2015 0:29               386
# 941195           340  6/30/2015 23:57    7/1/2015 0:03               153
# 941199           601  6/30/2015 23:57    7/1/2015 0:07               534
# 941203          1911  6/30/2015 23:58    7/1/2015 0:30               405
# 941210          1922  6/30/2015 23:58    7/1/2015 0:30               405
# 941212          1146  6/30/2015 23:59    7/1/2015 0:18               116
# 941215          1149  6/30/2015 23:59    7/1/2015 0:18               116
# 941216          3557  6/30/2015 23:59    7/1/2015 0:58               454
#
#                      start station name  start station latitude  \
# 4               University Pl & E 14 St               40.734927
# 25                   Carmine St & 6 Ave               40.730386
# 36                      8 Ave & W 52 St               40.763707
# 59        Washington St & Gansevoort St               40.739323
# 66                   Broadway & W 51 St               40.762288
# 69                   Broadway & W 51 St               40.762288
# 122                   E 5 St & Avenue C               40.722992
# 124            Washington Pl & Broadway               40.729039
# 125            Washington Pl & Broadway               40.729039
# 132              Barclay St & Church St               40.712912
# 134              Barclay St & Church St               40.712912
# 161          Greenwich Ave & Charles St               40.735238
# 165                     W 38 St & 8 Ave               40.754666
# 184                     W 38 St & 8 Ave               40.754666
# 238     Columbia Heights & Cranberry St               40.700379
# 240     Columbia Heights & Cranberry St               40.700379
# 329               Lafayette St & E 8 St               40.730287
# 401                  Broadway & W 32 St               40.748549
# 580                     8 Ave & W 31 St               40.750967
# 658             Adelphi St & Myrtle Ave               40.693083
# 675             Adelphi St & Myrtle Ave               40.693083
# 759          South End Ave & Liberty St               40.711512
# 780                  Broadway & W 29 St               40.746201
# 868            Lafayette St & Jersey St               40.724561
# 950                     W 41 St & 8 Ave               40.756405
# 975                     E 31 St & 3 Ave               40.743943
# 1039                 Carmine St & 6 Ave               40.730386
# 1048                    9 Ave & W 22 St               40.745497
# 1049                    9 Ave & W 22 St               40.745497
# 1064                    9 Ave & W 22 St               40.745497
# ...                                 ...                     ...
# 940998                  E 33 St & 2 Ave               40.744023
# 941002                  E 33 St & 2 Ave               40.744023
# 941012                  E 33 St & 2 Ave               40.744023
# 941034                  Dean St & 4 Ave               40.683125
# 941048         Cleveland Pl & Spring St               40.721816
# 941057                 Jay St & Tech Pl               40.695065
# 941058                 Jay St & Tech Pl               40.695065
# 941078          Lexington Ave & E 24 St               40.740259
# 941089                  E 33 St & 2 Ave               40.744023
# 941101                  E 33 St & 2 Ave               40.744023
# 941102                  E 33 St & 2 Ave               40.744023
# 941119                 Jay St & Tech Pl               40.695065
# 941120                 Jay St & Tech Pl               40.695065
# 941126                  W 11 St & 6 Ave               40.735324
# 941141               Kent Ave & S 11 St               40.708273
# 941149               Kent Ave & S 11 St               40.708273
# 941152         Lafayette St & Jersey St               40.724561
# 941161          Mercer St & Bleecker St               40.726795
# 941168          W 16 St & The High Line               40.743349
# 941177                  W 20 St & 7 Ave               40.742388
# 941178                  W 20 St & 7 Ave               40.742388
# 941192                  E 33 St & 2 Ave               40.744023
# 941193             Centre St & Worth St               40.714948
# 941195                  E 40 St & 5 Ave               40.752062
# 941199          Water - Whitehall Plaza               40.702551
# 941203    Washington St & Gansevoort St               40.739323
# 941210    Washington St & Gansevoort St               40.739323
# 941212                  W 17 St & 8 Ave               40.741776
# 941215                  W 17 St & 8 Ave               40.741776
# 941216                  E 51 St & 1 Ave               40.754557
#
#         start station longitude  end station id  \
# 4                    -73.992005             532
# 25                   -74.002150             358
# 36                   -73.985162             367
# 59                   -74.008119             380
# 66                   -73.983362             522
# 69                   -73.983362             522
# 122                  -73.979955             428
# 124                  -73.994046             507
# 125                  -73.994046             507
# 132                  -74.010202             468
# 134                  -74.010202             485
# 161                  -74.000271             546
# 165                  -73.991382             523
# 184                  -73.991382             492
# 238                  -73.995481             216
# 240                  -73.995481             216
# 329                  -73.990765             426
# 401                  -73.988084             250
# 580                  -73.994442             485
# 658                  -73.971789             324
# 675                  -73.971789             324
# 759                  -74.015756             147
# 780                  -73.988557             536
# 868                  -73.995653            2012
# 950                  -73.990026             491
# 975                  -73.979661             442
# 1039                 -74.002150             507
# 1048                 -74.001971             328
# 1049                 -74.001971             328
# 1064                 -74.001971             328
# ...                         ...             ...
# 940998               -73.976056             527
# 941002               -73.976056             527
# 941012               -73.976056             527
# 941034               -73.978951             532
# 941048               -73.997203             511
# 941057               -73.987167             387
# 941058               -73.987167             387
# 941078               -73.984092             539
# 941089               -73.976056             477
# 941101               -73.976056             477
# 941102               -73.976056             477
# 941119               -73.987167             387
# 941120               -73.987167             387
# 941126               -73.998004             251
# 941141               -73.968341             389
# 941149               -73.968341             389
# 941152               -73.995653             293
# 941161               -73.996951            2022
# 941168               -74.006818             498
# 941177               -73.997262             127
# 941178               -73.997262             127
# 941192               -73.976056             477
# 941193               -74.002345             282
# 941195               -73.981632             537
# 941199               -74.012723             355
# 941203               -74.008119             405
# 941210               -74.008119             405
# 941212               -74.001497             487
# 941215               -74.001497             487
# 941216               -73.965930             418
#
#                        end station name  end station latitude  \
# 4                       S 5 Pl & S 4 St             40.710451
# 25        Christopher St & Greenwich St             40.732916
# 36              E 53 St & Lexington Ave             40.758281
# 59                     W 4 St & 7 Ave S             40.734011
# 66              E 51 St & Lexington Ave             40.757148
# 69              E 51 St & Lexington Ave             40.757148
# 122                      E 3 St & 1 Ave             40.724677
# 124                     E 25 St & 2 Ave             40.739126
# 125                     E 25 St & 2 Ave             40.739126
# 132                  Broadway & W 55 St             40.765265
# 134                     W 37 St & 5 Ave             40.750380
# 161                E 30 St & Park Ave S             40.744449
# 165                     W 38 St & 8 Ave             40.754666
# 184                     W 33 St & 7 Ave             40.750200
# 238     Columbia Heights & Cranberry St             40.700379
# 240     Columbia Heights & Cranberry St             40.700379
# 329               West St & Chambers St             40.717548
# 401            Lafayette St & Jersey St             40.724561
# 580                     W 37 St & 5 Ave             40.750380
# 658             DeKalb Ave & Hudson Ave             40.689888
# 675             DeKalb Ave & Hudson Ave             40.689888
# 759            Greenwich St & Warren St             40.715422
# 780                     1 Ave & E 30 St             40.741444
# 868                     E 27 St & 1 Ave             40.739445
# 950                E 24 St & Park Ave S             40.740964
# 975                     W 27 St & 7 Ave             40.746647
# 1039                    E 25 St & 2 Ave             40.739126
# 1048            Watts St & Greenwich St             40.724055
# 1049            Watts St & Greenwich St             40.724055
# 1064            Watts St & Greenwich St             40.724055
# ...                                 ...                   ...
# 940998                  E 33 St & 2 Ave             40.744023
# 941002                  E 33 St & 2 Ave             40.744023
# 941012                  E 33 St & 2 Ave             40.744023
# 941034                  S 5 Pl & S 4 St             40.710451
# 941048               E 14 St & Avenue B             40.729387
# 941057          Centre St & Chambers St             40.712733
# 941058          Centre St & Chambers St             40.712733
# 941078   Metropolitan Ave & Bedford Ave             40.715348
# 941089                  W 41 St & 8 Ave             40.756405
# 941101                  W 41 St & 8 Ave             40.756405
# 941102                  W 41 St & 8 Ave             40.756405
# 941119          Centre St & Chambers St             40.712733
# 941120          Centre St & Chambers St             40.712733
# 941126              Mott St & Prince St             40.723180
# 941141              Broadway & Berry St             40.710446
# 941149              Broadway & Berry St             40.710446
# 941152            Lafayette St & E 8 St             40.730287
# 941161              E 59 St & Sutton Pl             40.758491
# 941168               Broadway & W 32 St             40.748549
# 941177            Barrow St & Hudson St             40.731724
# 941178            Barrow St & Hudson St             40.731724
# 941192                  W 41 St & 8 Ave             40.756405
# 941193               Kent Ave & S 11 St             40.708273
# 941195          Lexington Ave & E 24 St             40.740259
# 941199            Bayard St & Baxter St             40.716021
# 941203    Washington St & Gansevoort St             40.739323
# 941210    Washington St & Gansevoort St             40.739323
# 941212              E 20 St & FDR Drive             40.733143
# 941215              E 20 St & FDR Drive             40.733143
# 941216               Front St & Gold St             40.702240
#
#         end station longitude  bikeid  usertype  birth year  gender  ageS  \
# 4                  -73.960876   17028  Customer         NaN       0   NaN
# 25                 -74.007114   20136  Customer         NaN       0   NaN
# 36                 -73.970694   18392  Customer         NaN       0   NaN
# 59                 -74.002939   18573  Customer         NaN       0   NaN
# 66                 -73.972078   18892  Customer         NaN       0   NaN
# 69                 -73.972078   20014  Customer         NaN       0   NaN
# 122                -73.987834   17400  Customer         NaN       0   NaN
# 124                -73.979738   14656  Customer         NaN       0   NaN
# 125                -73.979738   14684  Customer         NaN       0   NaN
# 132                -73.981923   15067  Customer         NaN       0   NaN
# 134                -73.983390   20506  Customer         NaN       0   NaN
# 161                -73.983035   20633  Customer         NaN       0   NaN
# 165                -73.991382   16673  Customer         NaN       0   NaN
# 184                -73.990931   15045  Customer         NaN       0   NaN
# 238                -73.995481   18011  Customer         NaN       0   NaN
# 240                -73.995481   17325  Customer         NaN       0   NaN
# 329                -74.013221   14729  Customer         NaN       0   NaN
# 401                -73.995653   21375  Customer         NaN       0   NaN
# 580                -73.983390   20948  Customer         NaN       0   NaN
# 658                -73.981013   20187  Customer         NaN       0   NaN
# 675                -73.981013   19810  Customer         NaN       0   NaN
# 759                -74.011220   17740  Customer         NaN       0   NaN
# 780                -73.975361   16067  Customer         NaN       0   NaN
# 868                -73.976806   21245  Customer         NaN       0   NaN
# 950                -73.986022   20153  Customer         NaN       0   NaN
# 975                -73.993915   14990  Customer         NaN       0   NaN
# 1039               -73.979738   16671  Customer         NaN       0   NaN
# 1048               -74.009660   15556  Customer         NaN       0   NaN
# 1049               -74.009660   20961  Customer         NaN       0   NaN
# 1064               -74.009660   21674  Customer         NaN       0   NaN
# ...                       ...     ...       ...         ...     ...   ...
# 940998             -73.976056   17240  Customer         NaN       0   NaN
# 941002             -73.976056   20183  Customer         NaN       0   NaN
# 941012             -73.976056   16595  Customer         NaN       0   NaN
# 941034             -73.960876   17367  Customer         NaN       0   NaN
# 941048             -73.977724   17278  Customer         NaN       0   NaN
# 941057             -74.004607   20865  Customer         NaN       0   NaN
# 941058             -74.004607   14574  Customer         NaN       0   NaN
# 941078             -73.960241   16809  Customer         NaN       0   NaN
# 941089             -73.990026   17240  Customer         NaN       0   NaN
# 941101             -73.990026   16595  Customer         NaN       0   NaN
# 941102             -73.990026   20183  Customer         NaN       0   NaN
# 941119             -74.004607   16748  Customer         NaN       0   NaN
# 941120             -74.004607   18660  Customer         NaN       0   NaN
# 941126             -73.994800   14903  Customer         NaN       0   NaN
# 941141             -73.965251   22223  Customer         NaN       0   NaN
# 941149             -73.965251   15077  Customer         NaN       0   NaN
# 941152             -73.990765   15809  Customer         NaN       0   NaN
# 941161             -73.959206   18568  Customer         NaN       0   NaN
# 941168             -73.988084   15375  Customer         NaN       0   NaN
# 941177             -74.006744   17843  Customer         NaN       0   NaN
# 941178             -74.006744   20718  Customer         NaN       0   NaN
# 941192             -73.990026   14930  Customer         NaN       0   NaN
# 941193             -73.968341   16025  Customer         NaN       0   NaN
# 941195             -73.984092   20160  Customer         NaN       0   NaN
# 941199             -73.999744   17011  Customer         NaN       0   NaN
# 941203             -74.008119   18609  Customer         NaN       0   NaN
# 941210             -74.008119   14597  Customer         NaN       0   NaN
# 941212             -73.975739   18213  Customer         NaN       0   NaN
# 941215             -73.975739   21612  Customer         NaN       0   NaN
# 941216             -73.982578   19976  Customer         NaN       0   NaN
#
#         ageC  age
# 4        NaN  NaN
# 25       NaN  NaN
# 36       NaN  NaN
# 59       NaN  NaN
# 66       NaN  NaN
# 69       NaN  NaN
# 122      NaN  NaN
# 124      NaN  NaN
# 125      NaN  NaN
# 132      NaN  NaN
# 134      NaN  NaN
# 161      NaN  NaN
# 165      NaN  NaN
# 184      NaN  NaN
# 238      NaN  NaN
# 240      NaN  NaN
# 329      NaN  NaN
# 401      NaN  NaN
# 580      NaN  NaN
# 658      NaN  NaN
# 675      NaN  NaN
# 759      NaN  NaN
# 780      NaN  NaN
# 868      NaN  NaN
# 950      NaN  NaN
# 975      NaN  NaN
# 1039     NaN  NaN
# 1048     NaN  NaN
# 1049     NaN  NaN
# 1064     NaN  NaN
# ...      ...  ...
# 940998   NaN  NaN
# 941002   NaN  NaN
# 941012   NaN  NaN
# 941034   NaN  NaN
# 941048   NaN  NaN
# 941057   NaN  NaN
# 941058   NaN  NaN
# 941078   NaN  NaN
# 941089   NaN  NaN
# 941101   NaN  NaN
# 941102   NaN  NaN
# 941119   NaN  NaN
# 941120   NaN  NaN
# 941126   NaN  NaN
# 941141   NaN  NaN
# 941149   NaN  NaN
# 941152   NaN  NaN
# 941161   NaN  NaN
# 941168   NaN  NaN
# 941177   NaN  NaN
# 941178   NaN  NaN
# 941192   NaN  NaN
# 941193   NaN  NaN
# 941195   NaN  NaN
# 941199   NaN  NaN
# 941203   NaN  NaN
# 941210   NaN  NaN
# 941212   NaN  NaN
# 941215   NaN  NaN
# 941216   NaN  NaN
#
# [130381 rows x 18 columns]
